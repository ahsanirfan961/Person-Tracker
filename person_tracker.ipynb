# %%
import cv2
img=cv2.imread('people.webp')
prediction = model(img)[0]
for result in prediction.boxes.data.tolist():
        print(result)
        x1, y1, x2, y2, score, class_id = result
        cv2.rectangle(img, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
        cv2.putText(img, prediction.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)
cv2.imshow(f"Image ", img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 3
#       1 import cv2
#       2 img=cv2.imread('people.webp')
# ----> 3 prediction = model(img)[0]
#       4 for result in prediction.boxes.data.tolist():
#       5         print(result)
#
# File d:\Machine Learning\Projects\Python_Environment\GPU_Environment-pytorch\myenv\lib\site-packages\ultralytics\engine\model.py:172, in Model.__call__(self, source, stream, **kwargs)
#     143 def __call__(
#     144     self,
#     145     source: Union[str, Path, int, list, tuple, np.ndarray, torch.Tensor] = None,
#     146     stream: bool = False,
#     147     **kwargs,
#     148 ) -> list:
#     149     """
#     150     Alias for the predict method, enabling the model instance to be callable for predictions.
#     151
#    (...)
#     170         ...     print(f"Detected {len(r)} objects in image")
#     171     """
# --> 172     return self.predict(source, stream, **kwargs)
#
# File d:\Machine Learning\Projects\Python_Environment\GPU_Environment-pytorch\myenv\lib\site-packages\ultralytics\engine\model.py:562, in Model.predict(self, source, stream, predictor, **kwargs)
#     560 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     561     self.predictor.set_prompts(prompts)
# --> 562 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File d:\Machine Learning\Projects\Python_Environment\GPU_Environment-pytorch\myenv\lib\site-packages\ultralytics\engine\predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File d:\Machine Learning\Projects\Python_Environment\GPU_Environment-pytorch\myenv\lib\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File d:\Machine Learning\Projects\Python_Environment\GPU_Environment-pytorch\myenv\lib\site-packages\ultralytics\engine\predictor.py:234, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     232 # Warmup model
#     233 if not self.done_warmup:
# --> 234     self.model.warmup(imgsz=(1 if self.model.pt or self.model.triton else self.dataset.bs, 3, *self.imgsz))
#     235     self.done_warmup = True
#     237 self.seen, self.windows, self.batch = 0, [], None
#
# File d:\Machine Learning\Projects\Python_Environment\GPU_Environment-pytorch\myenv\lib\site-packages\ultralytics\nn\autobackend.py:633, in AutoBackend.warmup(self, imgsz)
#     626 def warmup(self, imgsz=(1, 3, 640, 640)):
#     627     """
#     628     Warm up the model by running one forward pass with a dummy input.
#     629
#     630     Args:
#     631         imgsz (tuple): The shape of the dummy input tensor in the format (batch_size, channels, height, width)
#     632     """
# --> 633     import torchvision  # noqa (import here so torchvision import time not recorded in postprocess time)
#     635     warmup_types = self.pt, self.jit, self.onnx, self.engine, self.saved_model, self.pb, self.triton, self.nn_module
#     636     if any(warmup_types) and (self.device.type != "cpu" or self.triton):
#
# File d:\Machine Learning\Projects\Python_Environment\GPU_Environment-pytorch\myenv\lib\site-packages\torchvision\__init__.py:6
#       3 from modulefinder import Module
#       5 import torch
# ----> 6 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils
#       8 from .extension import _HAS_OPS
#      10 try:
#
# File d:\Machine Learning\Projects\Python_Environment\GPU_Environment-pytorch\myenv\lib\site-packages\torchvision\_meta_registrations.py:26
#      20         return fn
#      22     return wrapper
#      25 @register_meta("roi_align")
# ---> 26 def meta_roi_align(input, rois, spatial_scale, pooled_height, pooled_width, sampling_ratio, aligned):
#      27     torch._check(rois.size(1) == 5, lambda: "rois must have shape as Tensor[K, 5]")
#      28     torch._check(
#      29         input.dtype == rois.dtype,
#      30         lambda: (
#    (...)
#      33         ),
#      34     )
#
# File d:\Machine Learning\Projects\Python_Environment\GPU_Environment-pytorch\myenv\lib\site-packages\torchvision\_meta_registrations.py:18, in register_meta.<locals>.wrapper(fn)
#      17 def wrapper(fn):
# ---> 18     if torchvision.extension._has_ops():
#      19         get_meta_lib().impl(getattr(getattr(torch.ops.torchvision, op_name), overload_name), fn)
#      20     return fn
#
# AttributeError: partially initialized module 'torchvision' has no attribute 'extension' (most likely due to a circular import)
